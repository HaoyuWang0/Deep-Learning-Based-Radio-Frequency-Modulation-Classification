# %%
# Visualize Results of RNN 2016 Model
from RNN2016_plot import *

RNN2016_visualize() # TODO: Update results data 'RNN2016Results.npz'
# Out:
# HERE

# %%
# Visualize Results of CNNLSTM 2016 Model
from CNNLSTM2016_plot import *

CNNLSTM2016_visualize() # TODO: Update results data 'CNNLSTM2016Results.npz'
